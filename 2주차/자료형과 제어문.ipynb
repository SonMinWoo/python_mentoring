# %%
a = 123
a
# Out:
# 123

# %%
b= 12.3
b
# Out:
# 12.3

# %%
c = 4.24e-2
c
# Out:
# 0.0424

# %%
a = 3
b = 4
a + b
# Out:
# 7

# %%
a - b
# Out:
# -1

# %%
a * b
# Out:
# 12

# %%
a / b
# Out:
# 0.75

# %%
a ** b
# Out:
# 81

# %%
a // b
# Out:
# 0

# %%
a % b
# Out:
# 3

# %%
import math
math.pow(8, 2)
# Out:
# 64.0

# %%
a = "hi, nice to meet you!"
a
# Out:
# 'hi, nice to meet you!'

# %%
a = "hi\n nice to meet you!"
print(a)
# Out:
# hi
#  nice to meet you!

# %%
name = '손민우'
age = 25
s = f"제 이름은 {name}이고, 나이는 {age}입니다."
ss = f"{s:>30}"
print(ss)
# Out:
#        제 이름은 손민우이고, 나이는 25입니다.

# %%
a = [1,2,3, ['a', 'b', 'c'], 4, "bc"]
a[3:5]
# Out:
# [['a', 'b', 'c'], 4]

# %%
a = [2,3,4]
a[0] ="a"
del a[1]
a.append("bc")
a.pop()
# Out:
# 'bc'

# %%
a = {"name": "민우", 3 : 3}
a["name"]
# Out:
# '민우'

# %%
a = [1,2,3, "b"]
b = [4, 5]
if 3 in a and 7 in b:
    print("3!")
elif 6 in b:
    print("4 in b")
else:
    print("ㅠㅠ")
# Out:
# ㅠㅠ

# %%
while True:
    print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %%
for _ in range(10):
    print("a")
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a

# %%
a = 3
b = 7
if a > 2:
    print("a")
if b > 2 :
    print("b")
# Out:
# a
# b
